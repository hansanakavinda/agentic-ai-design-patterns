# %%
# ==== Imports ====
from __future__ import annotations
import json
from dotenv import load_dotenv
import re, io, sys, traceback, json
from typing import Any, Dict, Optional
from tinydb import Query, where
from rich import print as rp

# Utility modules
import utils      # helper functions for prompting/printing
import inv_utils  # functions for inventory, transactions, schema building, and TinyDB seeding
from llm import agent

load_dotenv()
# Out:
# True

# %% [markdown]
# Create sample tables

# %%
db, inventory_tbl, transactions_tbl = inv_utils.seed_db()

# %%
utils.print_html(json.dumps(inventory_tbl.all(), indent=2), title="Inventory Table")
utils.print_html(json.dumps(transactions_tbl.all(), indent=2), title="Transactions Table")
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Inventory Table</div><pre><code>[
#   {
#     &quot;item_id&quot;: &quot;SG001&quot;,
#     &quot;name&quot;: &quot;Aviator&quot;,
#     &quot;description&quot;: &quot;Originally designed for pilots, these teardrop-shaped lenses with thin metal frames offer timeless appeal. The large lenses provide excellent coverage while the lightweight construction ensures comfort during long wear.&quot;,
#     &quot;quantity_in_stock&quot;: 22,
#     &quot;price&quot;: 80
#   },
#   {
#     &quot;item_id&quot;: &quot;SG002&quot;,
#     &quot;name&quot;: &quot;Wayfarer&quot;,
#     &quot;description&quot;: &quot;Featuring thick, angular frames that make a statement, these sunglasses combine retro charm with modern edge. The rectangular lenses and sturdy acetate construction create a confident look.&quot;,
#     &quot;quantity_in_stock&quot;: 6,
#     &quot;price&quot;: 95
#   },
#   {
#     &quot;item_id&quot;: &quot;SG003&quot;,
#     &quot;name&quot;: &quot;Mystique&quot;,
#     &quot;description&quot;: &quot;Inspired by 1950s glamour, these frames sweep upward at the outer corners to create an elegant, feminine silhouette. The subtle curves and often embellished temples add sophistication to any outfit.&quot;,
#     &quot;quantity_in_stock&quot;: 3,
#     &quot;price&quot;: 70
#   },
#   {
#     &quot;item_id&quot;: &quot;SG004&quot;,
#     &quot;name&quot;: &quot;Sport&quot;,
#     &quot;description&quot;: &quot;Designed for active lifestyles, these wraparound sunglasses feature a single curved lens that provides maximum coverage and wind protection. The lightweight, flexible frames include rubber grips.&quot;,
#     &quot;quantity_in_stock&quot;: 11,
#     &quot;price&quot;: 110
#   },
#   {
#     &quot;item_id&quot;: &quot;SG005&quot;,
#     &quot;name&quot;: &quot;Classic&quot;,
#     &quot;description&quot;: &quot;Classic round profile with minimalist metal frames, offering a timeless and versatile style that fits both casual and formal wear.&quot;,
#     &quot;quantity_in_stock&quot;: 7,
#     &quot;price&quot;: 60
#   },
#   {
#     &quot;item_id&quot;: &quot;SG006&quot;,
#     &quot;name&quot;: &quot;Moon&quot;,
#     &quot;description&quot;: &quot;Oversized round style with bold plastic frames, evoking retro aesthetics with a modern twist.&quot;,
#     &quot;quantity_in_stock&quot;: 10,
#     &quot;price&quot;: 120
#   }
# ]</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Transactions Table</div><pre><code>[
#   {
#     &quot;transaction_id&quot;: &quot;TXN001&quot;,
#     &quot;customer_name&quot;: &quot;OPENING_BALANCE&quot;,
#     &quot;transaction_summary&quot;: &quot;Daily opening register balance&quot;,
#     &quot;transaction_amount&quot;: 500.0,
#     &quot;balance_after_transaction&quot;: 500.0,
#     &quot;timestamp&quot;: &quot;2026-04-23T14:38:21.149711&quot;
#   },
#   {
#     &quot;transaction_id&quot;: &quot;TXN002&quot;,
#     &quot;customer_name&quot;: &quot;CUSTOMER&quot;,
#     &quot;transaction_summary&quot;: &quot;Purchase of 3 Classic sunglasses&quot;,
#     &quot;transaction_amount&quot;: 180.0,
#     &quot;balance_after_transaction&quot;: 680.0,
#     &quot;timestamp&quot;: &quot;2026-04-23T09:08:46.716508&quot;
#   },
#   {
#     &quot;transaction_id&quot;: &quot;TXN003&quot;,
#     &quot;customer_name&quot;: &quot;CUSTOMER&quot;,
#     &quot;transaction_summary&quot;: &quot;Purchase of 1 Aviator sunglasses&quot;,
#     &quot;transaction_amount&quot;: 80.0,
#     &quot;balance_after_transaction&quot;: 760.0,
#     &quot;timestamp&quot;: &quot;2026-04-23T09:08:46.725259&quot;
#   }
# ]</code></pre></div>

# %% [markdown]
# plan

# %%
PROMPT = """You are a senior data assistant. PLAN BY WRITING PYTHON CODE USING TINYDB.

Database Schema & Samples (read-only):
{schema_block}

Execution Environment (already imported/provided):
- Variables: db, inventory_tbl, transactions_tbl  # TinyDB Table objects
- Helpers: get_current_balance(tbl) -> float, next_transaction_id(tbl, prefix="TXN") -> str
- Natural language: user_request: str  # the original user message

PLANNING RULES (critical):
- Derive ALL filters/parameters from user_request (shape/keywords, price ranges "under/over/between", stock mentions,
  quantities, buy/return intent). Do NOT hard-code values.
- Build TinyDB queries dynamically with Query(). If a constraint isn't in user_request, don't apply it.
- Be conservative: if intent is ambiguous, do read-only (DRY RUN).

TRANSACTION POLICY (hard):
- Do NOT create aggregated multi-item transactions.
- If the request contains multiple items, create a separate transaction row PER ITEM.
- For each item:
  - compute its own line total (unit_price * qty),
  - insert ONE transaction with that amount,
  - update balance sequentially (balance += line_total),
  - update the item’s stock.
- If any requested item lacks sufficient stock, do NOT mutate anything; reply with STATUS="insufficient_stock".

HUMAN RESPONSE REQUIREMENT (hard):
- You MUST set a variable named `answer_text` (type str) with a short, customer-friendly sentence (1–2 lines).
- This sentence is the only user-facing message. No dataframes/JSON, no boilerplate disclaimers.
- If nothing matches, politely say so and offer a nearby alternative (closest style/price) or a next step.

ACTION POLICY:
- If the request clearly asks to change state (buy/purchase/return/restock/adjust):
    ACTION="mutate"; SHOULD_MUTATE=True; perform the change and write a matching transaction row.
  Otherwise:
    ACTION="read"; SHOULD_MUTATE=False; simulate and explain briefly as a dry run (in logs only).

FAILURE & EDGE-CASE HANDLING (must implement):
- Do not capture outer variables in Query.test. Pass them as explicit args.
- Always set a short `answer_text`. Also set a string `STATUS` to one of:
  "success", "no_match", "insufficient_stock", "invalid_request", "unsupported_intent".
- no_match: No items satisfy the filters → suggest the closest in style/price, or invite a different range.
- insufficient_stock: Item found but stock < requested qty → state available qty and offer the max you can fulfill.
- invalid_request: Unable to parse essential info (e.g., quantity for a purchase/return) → ask for the missing piece succinctly.
- unsupported_intent: The action is outside the store’s capabilities → provide the nearest supported alternative.
- In all cases, keep the tone helpful and concise (1–2 sentences). Put technical details (e.g., ACTION/DRY RUN) only in stdout logs.

OUTPUT CONTRACT:
- Return ONLY executable Python between these tags (no extra text):
  <execute_python>
  # your python
  </execute_python>

CODE CHECKLIST (follow in code):
1) Parse intent & constraints from user_request (regex ok).
2) Build TinyDB condition incrementally; query inventory_tbl.
3) If mutate: validate stock, update inventory, insert a transaction (new id, amount, balance, timestamp).
4) ALWAYS set:
   - `answer_text` (human sentence, required),
   - `STATUS` (see list above).
   Also print a brief log to stdout, e.g., "LOG: ACTION=read DRY_RUN=True STATUS=no_match".
5) Optional: set `answer_rows` or `answer_json` if useful, but `answer_text` is mandatory.

TONE EXAMPLES (for `answer_text`):
- success: "Yes, we have our Classic sunglasses, a round frame, for $60."
- no_match: "We don’t have round frames under $100 in stock right now, but our Moon round frame is available at $120."
- insufficient_stock: "We only have 1 pair of Classic left; I can reserve that for you."
- invalid_request: "I can help with that—how many pairs would you like to purchase?"
- unsupported_intent: "We can’t refurbish frames, but I can suggest similar new models."

Constraints:
- Use TinyDB Query for filtering. Standard library imports only if needed.
- Keep code clear and commented with numbered steps.

User request:
{question}
"""

# %% [markdown]
# planning in code

# %%
# ---------- 1) Code generation ----------
def generate_llm_code(
    prompt: str,
    *,
    inventory_tbl,
    transactions_tbl,
    model: str = "openai/gpt-oss-120b:free",
    temperature: float = 0.2,
) -> str:
    """
    Ask the LLM to produce a plan-with-code response.
    Returns the FULL assistant content (including surrounding text and tags).
    The actual code extraction happens later in execute_generated_code.
    """
    schema_block = inv_utils.build_schema_block(inventory_tbl, transactions_tbl)
    prompt = PROMPT.format(schema_block=schema_block, question=prompt)

    messages = [
            {
                "role": "system",
                "content": "You write safe, well-commented TinyDB code to handle data questions and updates."
            },
            {"role": "user", "content": prompt},
        ]

    content = agent(messages, model)
    return content

# %% [markdown]
# Testing sample prompt

# %% [markdown]
# before prompting the llm check manually to actual outcome

# %%
Item = Query()                    # Create a Query object to reference fields (e.g., Item.name, Item.description)

# Search the inventory table for documents where either the description OR the name
# contains the word "round" (case-insensitive). The check is done inline:
# - (v or "") ensures we handle None by converting it to an empty string
# - .lower() normalizes case
# - " round " enforces a crude word boundary (won't match "wraparound")
round_sunglasses = inventory_tbl.search(
    (Item.description.test(lambda v: " round " in ((v or "").lower()))) |
    (Item.name.test(        lambda v: " round " in ((v or "").lower())))
)

# Render the results as formatted JSON in the notebook UI
utils.print_html(json.dumps(round_sunglasses, indent=2), title="Inventory Status: Round Sunglasses")
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Inventory Status: Round Sunglasses</div><pre><code>[
#   {
#     &quot;item_id&quot;: &quot;SG005&quot;,
#     &quot;name&quot;: &quot;Classic&quot;,
#     &quot;description&quot;: &quot;Classic round profile with minimalist metal frames, offering a timeless and versatile style that fits both casual and formal wear.&quot;,
#     &quot;quantity_in_stock&quot;: 10,
#     &quot;price&quot;: 60
#   },
#   {
#     &quot;item_id&quot;: &quot;SG006&quot;,
#     &quot;name&quot;: &quot;Moon&quot;,
#     &quot;description&quot;: &quot;Oversized round style with bold plastic frames, evoking retro aesthetics with a modern twist.&quot;,
#     &quot;quantity_in_stock&quot;: 10,
#     &quot;price&quot;: 120
#   }
# ]</code></pre></div>

# %%
# Andrew's prompt from the lecture
prompt_round = "Do you have any round sunglasses in stock that are under $100?"

# Generate the plan-as-code (FULL content; may include <execute_python> tags)
full_content_round = generate_llm_code(
    prompt_round,
    inventory_tbl=inventory_tbl,
    transactions_tbl=transactions_tbl,
    model="openai/gpt-oss-120b:free"
)
full_content_round = full_content_round["content"]

# Inspect the LLM’s plan + code (no execution here)
utils.print_html(full_content_round, title="Plan with Code (Full Response)")
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Plan with Code (Full Response)</div><pre><code>&lt;execute_python&gt;
# import re
# from tinydb import Query
# from datetime import datetime
#
# # 1. Parse constraints from user request
# request = user_request.lower()
# need_round = bool(re.search(r&#x27;\bround\b&#x27;, request))
# price_limit = None
# price_match = re.search(r&#x27;under\s*\$?(\d+)&#x27;, request)
# if price_match:
#     price_limit = int(price_match.group(1))
#
# # 2. Build TinyDB query dynamically
# Item = Query()
# conditions = []
#
# if need_round:
#     # round may appear in description or name (e.g., &quot;Classic&quot;, &quot;Moon&quot;)
#     conditions.append((Item.description.test(lambda v: &#x27;round&#x27; in v.lower())) |
#                       (Item.name.test(lambda v: &#x27;round&#x27; in v.lower())))
#
# if price_limit is not None:
#     conditions.append(Item.price &lt; price_limit)
#
# # stock must be &gt;0
# conditions.append(Item.quantity_in_stock &gt; 0)
#
# # Combine conditions
# if conditions:
#     query = conditions[0]
#     for cond in conditions[1:]:
#         query = query &amp; cond
# else:
#     query = Item.test(lambda _: True)  # match all if no constraints (shouldn&#x27;t happen)
#
# # 3. Execute read‑only query
# matched_items = inventory_tbl.search(query)
#
# # 4. Prepare response
# if matched_items:
#     # Choose first matching item for brevity
#     item = matched_items[0]
#     answer_text = f&quot;Yes, we have our {item[&#x27;name&#x27;]} round sunglasses available for ${item[&#x27;price&#x27;]}.&quot;
#     STATUS = &quot;success&quot;
#     ACTION = &quot;read&quot;
#     SHOULD_MUTATE = False
#     print(f&quot;LOG: ACTION={ACTION} SHOULD_MUTATE={SHOULD_MUTATE} STATUS={STATUS} matches={len(matched_items)}&quot;)
# else:
#     # No exact match – suggest a closest alternative (any round style)
#     alt_query = (Item.description.test(lambda v: &#x27;round&#x27; in v.lower())) | (Item.name.test(lambda v: &#x27;round&#x27; in v.lower()))
#     alt_items = inventory_tbl.search(alt_query &amp; (Item.quantity_in_stock &gt; 0))
#     if alt_items:
#         alt = alt_items[0]
#         answer_text = (f&quot;We don’t have round sunglasses under ${price_limit} in stock, &quot;
#                        f&quot;but our {alt[&#x27;name&#x27;]} round style is available for ${alt[&#x27;price&#x27;]}.&quot;)
#         STATUS = &quot;no_match&quot;
#     else:
#         answer_text = &quot;We don’t have any round sunglasses in stock at the moment.&quot;
#         STATUS = &quot;no_match&quot;
#     ACTION = &quot;read&quot;
#     SHOULD_MUTATE = False
#     print(f&quot;LOG: ACTION={ACTION} SHOULD_MUTATE={SHOULD_MUTATE} STATUS={STATUS} matches=0&quot;)
# &lt;/execute_python&gt;</code></pre></div>

# %%
rp(full_content_round)
# Out:
# <execute_python>
# import re
# from tinydb import Query
# from datetime import datetime
#
# # 1. Parse constraints from user request
# request = user_request.lower()
# need_round = bool(re.search(r'\bround\b', request))
# price_limit = None
# price_match = re.search(r'under\s*\$?(\d+)', request)
# if price_match:
#     price_limit = int(price_match.group(1))
#
# # 2. Build TinyDB query dynamically
# Item = Query()
# conditions = []
#
# if need_round:
#     # round may appear in description or name (e.g., "Classic", "Moon")
#     conditions.append((Item.description.test(lambda v: 'round' in v.lower())) |
#                       (Item.name.test(lambda v: 'round' in v.lower())))
#
# if price_limit is not None:
#     conditions.append(Item.price < price_limit)
#
# # stock must be >0
# conditions.append(Item.quantity_in_stock > 0)
#
# # Combine conditions
# if conditions:
#     query = conditions[0]
#     for cond in conditions[1:]:
#         query = query & cond
# else:
#     query = Item.test(lambda _: True)  # match all if no constraints (shouldn't happen)
#
# # 3. Execute read‑only query
# matched_items = inventory_tbl.search(query)
#
# # 4. Prepare response
# if matched_items:
#     # Choose first matching item for brevity
#     item = matched_items[0]
#     answer_text = f"Yes, we have our {item['name']} round sunglasses available for ${item['price']}."
#     STATUS = "success"
#     ACTION = "read"
#     SHOULD_MUTATE = False
#     print(f"LOG: ACTION={ACTION} SHOULD_MUTATE={SHOULD_MUTATE} STATUS={STATUS} matches={len(matched_items)}")
# else:
#     # No exact match – suggest a closest alternative (any round style)
#     alt_query = (Item.description.test(lambda v: 'round' in v.lower())) | (Item.name.test(lambda v: 'round' in
# v.lower()))
#     alt_items = inventory_tbl.search(alt_query & (Item.quantity_in_stock > 0))
#     if alt_items:
#         alt = alt_items[0]
#         answer_text = (f"We don’t have round sunglasses under ${price_limit} in stock, "
#                        f"but our {alt['name']} round style is available for ${alt['price']}.")
#         STATUS = "no_match"
#     else:
#         answer_text = "We don’t have any round sunglasses in stock at the moment."
#         STATUS = "no_match"
#     ACTION = "read"
#     SHOULD_MUTATE = False
#     print(f"LOG: ACTION={ACTION} SHOULD_MUTATE={SHOULD_MUTATE} STATUS={STATUS} matches=0")
# </execute_python>

# %% [markdown]
# executer function

# %%
# --- Helper: extract code between <execute_python>...</execute_python> ---
def _extract_execute_block(text: str) -> str:
    """
    Returns the Python code inside <execute_python>...</execute_python>.
    If no tags are found, assumes 'text' is already raw Python code.
    """
    if not text:
        raise RuntimeError("Empty content passed to code executor.")
    m = re.search(r"<execute_python>(.*?)</execute_python>", text, re.DOTALL | re.IGNORECASE)
    return m.group(1).strip() if m else text.strip()


# ---------- 2) Code execution ----------
def execute_generated_code(
    code_or_content: str,
    *,
    db,
    inventory_tbl,
    transactions_tbl,
    user_request: Optional[str] = None,
) -> Dict[str, Any]:
    """
    Execute code in a controlled namespace.
    Accepts either raw Python code OR full content with <execute_python> tags.
    Returns minimal artifacts: stdout, error, and extracted answer.
    """
    # Extract code here (now centralized)
    code = _extract_execute_block(code_or_content)

    SAFE_GLOBALS = {
        "Query": Query,
        "get_current_balance": inv_utils.get_current_balance,
        "next_transaction_id": inv_utils.next_transaction_id,
        "user_request": user_request or "",
    }
    SAFE_LOCALS = {
        "db": db,
        "inventory_tbl": inventory_tbl,
        "transactions_tbl": transactions_tbl,
    }

    # Capture stdout from the executed code
    _stdout_buf, _old_stdout = io.StringIO(), sys.stdout
    sys.stdout = _stdout_buf
    err_text = None
    try:
        exec(code, SAFE_GLOBALS, SAFE_LOCALS)
    except Exception:
        err_text = traceback.format_exc()
    finally:
        sys.stdout = _old_stdout
    printed = _stdout_buf.getvalue().strip()

    # Extract possible answers set by the generated code
    answer = (
        SAFE_LOCALS.get("answer_text")
        or SAFE_LOCALS.get("answer_rows")
        or SAFE_LOCALS.get("answer_json")
    )


    return {
        "code": code,            # <- ya sin etiquetas
        "stdout": printed,
        "error": err_text,
        "answer": answer,
        "transactions_tbl": transactions_tbl.all(),  # For inspection
        "inventory_tbl": inventory_tbl.all(),  # For inspection
    }

# %%
# Execute the generated plan for the round-sunglasses question
result = execute_generated_code(
    full_content_round,          # the full LLM response you generated earlier
    db=db,
    inventory_tbl=inventory_tbl,
    transactions_tbl=transactions_tbl,
    user_request=prompt_round, # e.g., "Do you have any round sunglasses in stock that are under $100?"
)

rp(result["answer"])
# Out:
# Yes, we have our Classic round sunglasses available for $60.

# %%
prompt_aviator = "Return 2 Aviator sunglasses I bought last week."

# Generate the plan-as-code (FULL content; may include <execute_python> tags)
full_content_aviator = generate_llm_code(
    prompt_aviator,
    inventory_tbl=inventory_tbl,
    transactions_tbl=transactions_tbl,
)

full_content_aviator = full_content_aviator["content"]

# Inspect the LLM’s plan + code (no execution here)
utils.print_html(full_content_aviator, title="Plan with Code (Full Response)")
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Plan with Code (Full Response)</div><pre><code>&lt;execute_python&gt;
# import re
# from tinydb import Query
# from datetime import datetime
#
# # 1. Parse user request for intent, item name, and quantity
# request = user_request.lower()
# intent = &quot;return&quot; if re.search(r&quot;\breturn\b&quot;, request) else &quot;buy&quot;
# quantity_match = re.search(r&quot;(\d+)\s+.*?(\w+)&quot;, request)
# quantity = int(quantity_match.group(1)) if quantity_match else None
# item_name_match = re.search(r&quot;(aviator|wayfarer|mystique|sport|classic|moon)&quot;, request)
# item_name = item_name_match.group(1).capitalize() if item_name_match else None
#
# # Initialize response placeholders
# answer_text = &quot;&quot;
# STATUS = &quot;invalid_request&quot;
#
# # 2. Validate essential info
# if not item_name:
#     STATUS = &quot;invalid_request&quot;
#     answer_text = &quot;Which style would you like to return?&quot;
# elif not quantity:
#     STATUS = &quot;invalid_request&quot;
#     answer_text = f&quot;How many {item_name} sunglasses are you returning?&quot;
# else:
#     # 3. Build query for the specific item
#     q = Query()
#     condition = (q.name == item_name)
#
#     # 4. Retrieve matching inventory rows
#     matches = inventory_tbl.search(condition)
#
#     if not matches:
#         STATUS = &quot;no_match&quot;
#         answer_text = f&quot;We don’t have any {item_name} sunglasses in our catalog right now.&quot;
#     else:
#         item = matches[0]  # assume unique name
#         # 5. For returns, we just need to accept any quantity (no stock check needed)
#         #    Compute transaction amount (refund): negative of total price
#         line_total = -item[&#x27;price&#x27;] * quantity  # negative for refund
#
#         # 6. Perform mutation: update stock and insert transaction
#         # Update inventory stock
#         new_stock = item[&#x27;quantity_in_stock&#x27;] + quantity
#         inventory_tbl.update({&#x27;quantity_in_stock&#x27;: new_stock}, condition)
#
#         # Prepare transaction record
#         txn_id = next_transaction_id(transactions_tbl, prefix=&quot;TXN&quot;)
#         current_balance = get_current_balance(transactions_tbl)
#         new_balance = current_balance + line_total
#         timestamp = datetime.utcnow().isoformat()
#
#         transaction_record = {
#             &#x27;transaction_id&#x27;: txn_id,
#             &#x27;customer_name&#x27;: &#x27;RETURN&#x27;,
#             &#x27;transaction_summary&#x27;: f&#x27;Return of {quantity} {item_name} sunglasses&#x27;,
#             &#x27;transaction_amount&#x27;: line_total,
#             &#x27;balance_after_transaction&#x27;: new_balance,
#             &#x27;timestamp&#x27;: timestamp
#         }
#         transactions_tbl.insert(transaction_record)
#
#         STATUS = &quot;success&quot;
#         answer_text = f&quot;Returned {quantity} {item_name} sunglasses. Your refund is ${-line_total}.&quot;
#
# # Log for debugging
# print(f&quot;LOG: ACTION={&#x27;mutate&#x27; if STATUS==&#x27;success&#x27; else &#x27;read&#x27;} STATUS={STATUS}&quot;)
#
# &lt;/execute_python&gt;</code></pre></div>

# %%
rp(full_content_aviator)
# Out:
# <execute_python>
# import re
# from tinydb import Query
# from datetime import datetime
#
# # 1. Parse user request for intent, item name, and quantity
# request = user_request.lower()
# intent = "return" if re.search(r"\breturn\b", request) else "buy"
# quantity_match = re.search(r"(\d+)\s+.*?(\w+)", request)
# quantity = int(quantity_match.group(1)) if quantity_match else None
# item_name_match = re.search(r"(aviator|wayfarer|mystique|sport|classic|moon)", request)
# item_name = item_name_match.group(1).capitalize() if item_name_match else None
#
# # Initialize response placeholders
# answer_text = ""
# STATUS = "invalid_request"
#
# # 2. Validate essential info
# if not item_name:
#     STATUS = "invalid_request"
#     answer_text = "Which style would you like to return?"
# elif not quantity:
#     STATUS = "invalid_request"
#     answer_text = f"How many {item_name} sunglasses are you returning?"
# else:
#     # 3. Build query for the specific item
#     q = Query()
#     condition = (q.name == item_name)
#
#     # 4. Retrieve matching inventory rows
#     matches = inventory_tbl.search(condition)
#
#     if not matches:
#         STATUS = "no_match"
#         answer_text = f"We don’t have any {item_name} sunglasses in our catalog right now."
#     else:
#         item = matches[0]  # assume unique name
#         # 5. For returns, we just need to accept any quantity (no stock check needed)
#         #    Compute transaction amount (refund): negative of total price
#         line_total = -item['price'] * quantity  # negative for refund
#
#         # 6. Perform mutation: update stock and insert transaction
#         # Update inventory stock
#         new_stock = item['quantity_in_stock'] + quantity
#         inventory_tbl.update({'quantity_in_stock': new_stock}, condition)
#
#         # Prepare transaction record
#         txn_id = next_transaction_id(transactions_tbl, prefix="TXN")
#         current_balance = get_current_balance(transactions_tbl)
#         new_balance = current_balance + line_total
#         timestamp = datetime.utcnow().isoformat()
#
#         transaction_record = {
#             'transaction_id': txn_id,
#             'customer_name': 'RETURN',
#             'transaction_summary': f'Return of {quantity} {item_name} sunglasses',
#             'transaction_amount': line_total,
#             'balance_after_transaction': new_balance,
#             'timestamp': timestamp
#         }
#         transactions_tbl.insert(transaction_record)
#
#         STATUS = "success"
#         answer_text = f"Returned {quantity} {item_name} sunglasses. Your refund is ${-line_total}."
#
# # Log for debugging
# print(f"LOG: ACTION={'mutate' if STATUS=='success' else 'read'} STATUS={STATUS}")
#
# </execute_python>

# %%
# Execute the generated plan for the round-sunglasses question
result = execute_generated_code(
    full_content_aviator,          # the full LLM response you generated earlier
    db=db,
    inventory_tbl=inventory_tbl,
    transactions_tbl=transactions_tbl,
    user_request=prompt_aviator, # e.g., "Return 2 aviator sunglasses I bought last week."
)

rp(result["answer"])
# Out:
# Returned 2 Aviator sunglasses. Your refund is $160.

# %% [markdown]
# Customer service agent

# %%
def customer_service_agent(
    question: str,
    *,
    db,
    inventory_tbl,
    transactions_tbl,
    reseed: bool = False,
) -> dict:
    """
    End-to-end helper:
      1) (Optional) reseed inventory & transactions
      2) Generate plan-as-code from `question`
      3) Execute in a controlled namespace
      4) Render before/after snapshots and return artifacts

    Returns:
      {
        "full_content": <raw LLM response (may include <execute_python> tags)>,
        "exec": {
            "code": <extracted python>,
            "stdout": <plan logs>,
            "error": <traceback or None>,
            "answer": <answer_text/rows/json>,
            "inventory_after": [...],
            "transactions_after": [...]
        }
      }
    """
    # 0) Optional reseed
    if reseed:
        inv_utils.create_inventory()
        inv_utils.create_transactions()

    # 1) Show the question
    utils.print_html(question, title="User Question")

    # 2) Generate plan-as-code (FULL content)
    full_content = generate_llm_code(
        question,
        inventory_tbl=inventory_tbl,
        transactions_tbl=transactions_tbl,
    )
    full_content = full_content["content"]
    
    utils.print_html(full_content, title="Plan with Code (Full Response)")

    # 3) Before snapshots
    utils.print_html(json.dumps(inventory_tbl.all(), indent=2), title="Inventory Table · Before")
    utils.print_html(json.dumps(transactions_tbl.all(), indent=2), title="Transactions Table · Before")

    # 4) Execute
    exec_res = execute_generated_code(
        full_content,
        db=db,
        inventory_tbl=inventory_tbl,
        transactions_tbl=transactions_tbl,
        user_request=question,
    )

    # 5) After snapshots + final answer
    utils.print_html(exec_res["answer"], title="Plan Execution · Extracted Answer")
    utils.print_html(json.dumps(inventory_tbl.all(), indent=2), title="Inventory Table · After")
    utils.print_html(json.dumps(transactions_tbl.all(), indent=2), title="Transactions Table · After")

    # 6) Return artifacts
    return {
        "full_content": full_content,
        "exec": {
            "code": exec_res["code"],
            "stdout": exec_res["stdout"],
            "error": exec_res["error"],
            "answer": exec_res["answer"],
            "inventory_after": inventory_tbl.all(),
            "transactions_after": transactions_tbl.all(),
        },
    }

# %%
prompt = "I want to buy 3 pairs of classic sunglasses and 1 pair of aviator sunglasses."

out = customer_service_agent(
    prompt,
    db=db,
    inventory_tbl=inventory_tbl,
    transactions_tbl=transactions_tbl,
    reseed=True,   # set False to keep current state of the inventory and the transactions
)
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">User Question</div><pre><code>I want to buy 3 pairs of classic sunglasses and 1 pair of aviator sunglasses.</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Plan with Code (Full Response)</div><pre><code>&lt;execute_python&gt;
# import re
# from tinydb import Query
# from datetime import datetime
#
# # 1. Parse request for items and quantities
# request = user_request.lower()
# # pattern matches &quot;&lt;qty&gt; pair(s) of &lt;name&gt; sunglasses&quot;
# pattern = re.compile(r&#x27;(\d+)\s+pair(?:s)?\s+of\s+([a-zA-Z]+)\s+sunglasses&#x27;)
# matches = pattern.findall(request)
#
# # Prepare list of (item_name, qty) preserving order
# order_items = []
# for qty_str, name in matches:
#     order_items.append((name.strip().capitalize(), int(qty_str)))  # capitalize to match DB names
#
# if not order_items:
#     answer_text = &quot;I couldn’t find any items to purchase in your request. Could you specify the styles and quantities?&quot;
#     STATUS = &quot;invalid_request&quot;
#     print(f&quot;LOG: ACTION=read DRY_RUN=True STATUS={STATUS}&quot;)
# else:
#     # 2. Initialize transaction handling
#     ACTION = &quot;mutate&quot;
#     SHOULD_MUTATE = True
#     balance = get_current_balance(transactions_tbl)  # existing balance
#     txn_ids = []  # keep for logging if needed
#     insufficient = False
#     insufficient_msg = &quot;&quot;
#     # 3. Process each item sequentially
#     for style, qty in order_items:
#         # Build query for the style name
#         Item = Query()
#         results = inventory_tbl.search(Item.name == style)
#         if not results:
#             # no match for this style
#             answer_text = f&quot;We don’t have {style} sunglasses in stock right now.&quot;
#             STATUS = &quot;no_match&quot;
#             print(f&quot;LOG: ACTION=read DRY_RUN=True STATUS={STATUS}&quot;)
#             break
#
#         item = results[0]  # assume unique name
#         stock = item[&#x27;quantity_in_stock&#x27;]
#         price = item[&#x27;price&#x27;]
#         if stock &lt; qty:
#             insufficient = True
#             insufficient_msg = f&quot;We only have {stock} pair{&#x27;s&#x27; if stock!=1 else &#x27;&#x27;} of {style} left.&quot;
#             # Do not mutate anything if any item insufficient
#             break
#
#         # Sufficient stock – perform mutation
#         line_total = price * qty
#         # Update inventory stock
#         inventory_tbl.update({&#x27;quantity_in_stock&#x27;: stock - qty}, Item.item_id == item[&#x27;item_id&#x27;])
#         # Update balance
#         balance += line_total
#         # Insert transaction
#         txn_id = next_transaction_id(transactions_tbl, prefix=&quot;TXN&quot;)
#         txn = {
#             &#x27;transaction_id&#x27;: txn_id,
#             &#x27;customer_name&#x27;: &#x27;CUSTOMER&#x27;,
#             &#x27;transaction_summary&#x27;: f&#x27;Purchase of {qty} {style} sunglasses&#x27;,
#             &#x27;transaction_amount&#x27;: float(line_total),
#             &#x27;balance_after_transaction&#x27;: float(balance),
#             &#x27;timestamp&#x27;: datetime.utcnow().isoformat()
#         }
#         transactions_tbl.insert(txn)
#         txn_ids.append(txn_id)
#
#     # 4. Set final response based on outcome
#     if insufficient:
#         # rollback not needed because we stopped before any mutation for this item,
#         # but earlier items may have already been mutated – per policy we should not mutate at all.
#         # To honor policy, we revert any prior updates.
#         # Simple approach: reload original stock values from DB backup is unavailable,
#         # so we treat this as a dry run instead of mutation.
#         # We&#x27;ll set STATUS and answer_text without committing changes.
#         # Since we already mutated earlier items, we need to undo:
#         # Re-add the deducted stock and revert balance and delete inserted transactions.
#         # Undo loop for items already processed (order_items before the failing one)
#         processed = order_items[:order_items.index((style, qty))]
#         for p_style, p_qty in processed:
#             p_item = inventory_tbl.search(Item.name == p_style)[0]
#             # restore stock
#             inventory_tbl.update({&#x27;quantity_in_stock&#x27;: p_item[&#x27;quantity_in_stock&#x27;] + p_qty},
#                                  Item.item_id == p_item[&#x27;item_id&#x27;])
#         # Remove inserted transactions
#         for tid in txn_ids:
#             transactions_tbl.remove(Query().transaction_id == tid)
#         answer_text = insufficient_msg
#         STATUS = &quot;insufficient_stock&quot;
#         print(f&quot;LOG: ACTION=mutate SHOULD_MUTATE=False STATUS={STATUS}&quot;)
#     elif &#x27;answer_text&#x27; not in locals():
#         answer_text = &quot;Your purchase is confirmed: 3 Classic and 1 Aviator sunglasses have been reserved for you.&quot;
#         STATUS = &quot;success&quot;
#         print(f&quot;LOG: ACTION={ACTION} SHOULD_MUTATE=True STATUS={STATUS}&quot;)
#     # else answer_text already set for no_match case
# &lt;/execute_python&gt;</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Inventory Table · Before</div><pre><code>[
#   {
#     &quot;item_id&quot;: &quot;SG001&quot;,
#     &quot;name&quot;: &quot;Aviator&quot;,
#     &quot;description&quot;: &quot;Originally designed for pilots, these teardrop-shaped lenses with thin metal frames offer timeless appeal. The large lenses provide excellent coverage while the lightweight construction ensures comfort during long wear.&quot;,
#     &quot;quantity_in_stock&quot;: 23,
#     &quot;price&quot;: 80
#   },
#   {
#     &quot;item_id&quot;: &quot;SG002&quot;,
#     &quot;name&quot;: &quot;Wayfarer&quot;,
#     &quot;description&quot;: &quot;Featuring thick, angular frames that make a statement, these sunglasses combine retro charm with modern edge. The rectangular lenses and sturdy acetate construction create a confident look.&quot;,
#     &quot;quantity_in_stock&quot;: 6,
#     &quot;price&quot;: 95
#   },
#   {
#     &quot;item_id&quot;: &quot;SG003&quot;,
#     &quot;name&quot;: &quot;Mystique&quot;,
#     &quot;description&quot;: &quot;Inspired by 1950s glamour, these frames sweep upward at the outer corners to create an elegant, feminine silhouette. The subtle curves and often embellished temples add sophistication to any outfit.&quot;,
#     &quot;quantity_in_stock&quot;: 3,
#     &quot;price&quot;: 70
#   },
#   {
#     &quot;item_id&quot;: &quot;SG004&quot;,
#     &quot;name&quot;: &quot;Sport&quot;,
#     &quot;description&quot;: &quot;Designed for active lifestyles, these wraparound sunglasses feature a single curved lens that provides maximum coverage and wind protection. The lightweight, flexible frames include rubber grips.&quot;,
#     &quot;quantity_in_stock&quot;: 11,
#     &quot;price&quot;: 110
#   },
#   {
#     &quot;item_id&quot;: &quot;SG005&quot;,
#     &quot;name&quot;: &quot;Classic&quot;,
#     &quot;description&quot;: &quot;Classic round profile with minimalist metal frames, offering a timeless and versatile style that fits both casual and formal wear.&quot;,
#     &quot;quantity_in_stock&quot;: 10,
#     &quot;price&quot;: 60
#   },
#   {
#     &quot;item_id&quot;: &quot;SG006&quot;,
#     &quot;name&quot;: &quot;Moon&quot;,
#     &quot;description&quot;: &quot;Oversized round style with bold plastic frames, evoking retro aesthetics with a modern twist.&quot;,
#     &quot;quantity_in_stock&quot;: 10,
#     &quot;price&quot;: 120
#   }
# ]</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Transactions Table · Before</div><pre><code>[
#   {
#     &quot;transaction_id&quot;: &quot;TXN001&quot;,
#     &quot;customer_name&quot;: &quot;OPENING_BALANCE&quot;,
#     &quot;transaction_summary&quot;: &quot;Daily opening register balance&quot;,
#     &quot;transaction_amount&quot;: 500.0,
#     &quot;balance_after_transaction&quot;: 500.0,
#     &quot;timestamp&quot;: &quot;2026-04-23T14:38:21.149711&quot;
#   }
# ]</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Plan Execution · Extracted Answer</div><pre><code>Your purchase is confirmed: 3 Classic and 1 Aviator sunglasses have been reserved for you.</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Inventory Table · After</div><pre><code>[
#   {
#     &quot;item_id&quot;: &quot;SG001&quot;,
#     &quot;name&quot;: &quot;Aviator&quot;,
#     &quot;description&quot;: &quot;Originally designed for pilots, these teardrop-shaped lenses with thin metal frames offer timeless appeal. The large lenses provide excellent coverage while the lightweight construction ensures comfort during long wear.&quot;,
#     &quot;quantity_in_stock&quot;: 22,
#     &quot;price&quot;: 80
#   },
#   {
#     &quot;item_id&quot;: &quot;SG002&quot;,
#     &quot;name&quot;: &quot;Wayfarer&quot;,
#     &quot;description&quot;: &quot;Featuring thick, angular frames that make a statement, these sunglasses combine retro charm with modern edge. The rectangular lenses and sturdy acetate construction create a confident look.&quot;,
#     &quot;quantity_in_stock&quot;: 6,
#     &quot;price&quot;: 95
#   },
#   {
#     &quot;item_id&quot;: &quot;SG003&quot;,
#     &quot;name&quot;: &quot;Mystique&quot;,
#     &quot;description&quot;: &quot;Inspired by 1950s glamour, these frames sweep upward at the outer corners to create an elegant, feminine silhouette. The subtle curves and often embellished temples add sophistication to any outfit.&quot;,
#     &quot;quantity_in_stock&quot;: 3,
#     &quot;price&quot;: 70
#   },
#   {
#     &quot;item_id&quot;: &quot;SG004&quot;,
#     &quot;name&quot;: &quot;Sport&quot;,
#     &quot;description&quot;: &quot;Designed for active lifestyles, these wraparound sunglasses feature a single curved lens that provides maximum coverage and wind protection. The lightweight, flexible frames include rubber grips.&quot;,
#     &quot;quantity_in_stock&quot;: 11,
#     &quot;price&quot;: 110
#   },
#   {
#     &quot;item_id&quot;: &quot;SG005&quot;,
#     &quot;name&quot;: &quot;Classic&quot;,
#     &quot;description&quot;: &quot;Classic round profile with minimalist metal frames, offering a timeless and versatile style that fits both casual and formal wear.&quot;,
#     &quot;quantity_in_stock&quot;: 7,
#     &quot;price&quot;: 60
#   },
#   {
#     &quot;item_id&quot;: &quot;SG006&quot;,
#     &quot;name&quot;: &quot;Moon&quot;,
#     &quot;description&quot;: &quot;Oversized round style with bold plastic frames, evoking retro aesthetics with a modern twist.&quot;,
#     &quot;quantity_in_stock&quot;: 10,
#     &quot;price&quot;: 120
#   }
# ]</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Transactions Table · After</div><pre><code>[
#   {
#     &quot;transaction_id&quot;: &quot;TXN001&quot;,
#     &quot;customer_name&quot;: &quot;OPENING_BALANCE&quot;,
#     &quot;transaction_summary&quot;: &quot;Daily opening register balance&quot;,
#     &quot;transaction_amount&quot;: 500.0,
#     &quot;balance_after_transaction&quot;: 500.0,
#     &quot;timestamp&quot;: &quot;2026-04-23T14:38:21.149711&quot;
#   },
#   {
#     &quot;transaction_id&quot;: &quot;TXN002&quot;,
#     &quot;customer_name&quot;: &quot;CUSTOMER&quot;,
#     &quot;transaction_summary&quot;: &quot;Purchase of 3 Classic sunglasses&quot;,
#     &quot;transaction_amount&quot;: 180.0,
#     &quot;balance_after_transaction&quot;: 680.0,
#     &quot;timestamp&quot;: &quot;2026-04-23T09:08:46.716508&quot;
#   },
#   {
#     &quot;transaction_id&quot;: &quot;TXN003&quot;,
#     &quot;customer_name&quot;: &quot;CUSTOMER&quot;,
#     &quot;transaction_summary&quot;: &quot;Purchase of 1 Aviator sunglasses&quot;,
#     &quot;transaction_amount&quot;: 80.0,
#     &quot;balance_after_transaction&quot;: 760.0,
#     &quot;timestamp&quot;: &quot;2026-04-23T09:08:46.725259&quot;
#   }
# ]</code></pre></div>

# %%
rp(out)
# Out:
# {
#     'full_content': '<execute_python>\nimport re\nfrom tinydb import Query\nfrom datetime import datetime\n\n# 1.
# Parse request for items and quantities\nrequest = user_request.lower()\n# pattern matches "<qty> pair(s) of <name>
# sunglasses"\npattern = re.compile(r\'(\\d+)\\s+pair(?:s)?\\s+of\\s+([a-zA-Z]+)\\s+sunglasses\')\nmatches =
# pattern.findall(request)\n\n# Prepare list of (item_name, qty) preserving order\norder_items = []\nfor qty_str,
# name in matches:\n    order_items.append((name.strip().capitalize(), int(qty_str)))  # capitalize to match DB
# names\n\nif not order_items:\n    answer_text = "I couldn’t find any items to purchase in your request. Could you
# specify the styles and quantities?"\n    STATUS = "invalid_request"\n    print(f"LOG: ACTION=read DRY_RUN=True
# STATUS={STATUS}")\nelse:\n    # 2. Initialize transaction handling\n    ACTION = "mutate"\n    SHOULD_MUTATE =
# True\n    balance = get_current_balance(transactions_tbl)  # existing balance\n    txn_ids = []  # keep for logging
# if needed\n    insufficient = False\n    insufficient_msg = ""\n    # 3. Process each item sequentially\n    for
# style, qty in order_items:\n        # Build query for the style name\n        Item = Query()\n        results =
# inventory_tbl.search(Item.name == style)\n        if not results:\n            # no match for this style\n
# answer_text = f"We don’t have {style} sunglasses in stock right now."\n            STATUS = "no_match"\n
# print(f"LOG: ACTION=read DRY_RUN=True STATUS={STATUS}")\n            break\n\n        item = results[0]  # assume
# unique name\n        stock = item[\'quantity_in_stock\']\n        price = item[\'price\']\n        if stock <
# qty:\n            insufficient = True\n            insufficient_msg = f"We only have {stock} pair{\'s\' if stock!=1
# else \'\'} of {style} left."\n            # Do not mutate anything if any item insufficient\n            break\n\n
# # Sufficient stock – perform mutation\n        line_total = price * qty\n        # Update inventory stock\n
# inventory_tbl.update({\'quantity_in_stock\': stock - qty}, Item.item_id == item[\'item_id\'])\n        # Update
# balance\n        balance += line_total\n        # Insert transaction\n        txn_id =
# next_transaction_id(transactions_tbl, prefix="TXN")\n        txn = {\n            \'transaction_id\': txn_id,\n
# \'customer_name\': \'CUSTOMER\',\n            \'transaction_summary\': f\'Purchase of {qty} {style} sunglasses\',\n
# \'transaction_amount\': float(line_total),\n            \'balance_after_transaction\': float(balance),\n
# \'timestamp\': datetime.utcnow().isoformat()\n        }\n        transactions_tbl.insert(txn)\n
# txn_ids.append(txn_id)\n\n    # 4. Set final response based on outcome\n    if insufficient:\n        # rollback
# not needed because we stopped before any mutation for this item,\n        # but earlier items may have already been
# mutated – per policy we should not mutate at all.\n        # To honor policy, we revert any prior updates.\n
# # Simple approach: reload original stock values from DB backup is unavailable,\n        # so we treat this as a dry
# run instead of mutation.\n        # We\'ll set STATUS and answer_text without committing changes.\n        # Since
# we already mutated earlier items, we need to undo:\n        # Re-add the deducted stock and revert balance and
# delete inserted transactions.\n        # Undo loop for items already processed (order_items before the failing
# one)\n        processed = order_items[:order_items.index((style, qty))]\n        for p_style, p_qty in processed:\n
# p_item = inventory_tbl.search(Item.name == p_style)[0]\n            # restore stock\n
# inventory_tbl.update({\'quantity_in_stock\': p_item[\'quantity_in_stock\'] + p_qty},\n
# Item.item_id == p_item[\'item_id\'])\n        # Remove inserted transactions\n        for tid in txn_ids:\n
# transactions_tbl.remove(Query().transaction_id == tid)\n        answer_text = insufficient_msg\n        STATUS =
# "insufficient_stock"\n        print(f"LOG: ACTION=mutate SHOULD_MUTATE=False STATUS={STATUS}")\n    elif
# \'answer_text\' not in locals():\n        answer_text = "Your purchase is confirmed: 3 Classic and 1 Aviator
# sunglasses have been reserved for you."\n        STATUS = "success"\n        print(f"LOG: ACTION={ACTION}
# SHOULD_MUTATE=True STATUS={STATUS}")\n    # else answer_text already set for no_match case\n</execute_python>',
#     'exec': {
#         'code': 'import re\nfrom tinydb import Query\nfrom datetime import datetime\n\n# 1. Parse request for items
# and quantities\nrequest = user_request.lower()\n# pattern matches "<qty> pair(s) of <name> sunglasses"\npattern =
# re.compile(r\'(\\d+)\\s+pair(?:s)?\\s+of\\s+([a-zA-Z]+)\\s+sunglasses\')\nmatches = pattern.findall(request)\n\n#
# Prepare list of (item_name, qty) preserving order\norder_items = []\nfor qty_str, name in matches:\n
# order_items.append((name.strip().capitalize(), int(qty_str)))  # capitalize to match DB names\n\nif not
# order_items:\n    answer_text = "I couldn’t find any items to purchase in your request. Could you specify the
# styles and quantities?"\n    STATUS = "invalid_request"\n    print(f"LOG: ACTION=read DRY_RUN=True
# STATUS={STATUS}")\nelse:\n    # 2. Initialize transaction handling\n    ACTION = "mutate"\n    SHOULD_MUTATE =
# True\n    balance = get_current_balance(transactions_tbl)  # existing balance\n    txn_ids = []  # keep for logging
# if needed\n    insufficient = False\n    insufficient_msg = ""\n    # 3. Process each item sequentially\n    for
# style, qty in order_items:\n        # Build query for the style name\n        Item = Query()\n        results =
# inventory_tbl.search(Item.name == style)\n        if not results:\n            # no match for this style\n
# answer_text = f"We don’t have {style} sunglasses in stock right now."\n            STATUS = "no_match"\n
# print(f"LOG: ACTION=read DRY_RUN=True STATUS={STATUS}")\n            break\n\n        item = results[0]  # assume
# unique name\n        stock = item[\'quantity_in_stock\']\n        price = item[\'price\']\n        if stock <
# qty:\n            insufficient = True\n            insufficient_msg = f"We only have {stock} pair{\'s\' if stock!=1
# else \'\'} of {style} left."\n            # Do not mutate anything if any item insufficient\n            break\n\n
# # Sufficient stock – perform mutation\n        line_total = price * qty\n        # Update inventory stock\n
# inventory_tbl.update({\'quantity_in_stock\': stock - qty}, Item.item_id == item[\'item_id\'])\n        # Update
# balance\n        balance += line_total\n        # Insert transaction\n        txn_id =
# next_transaction_id(transactions_tbl, prefix="TXN")\n        txn = {\n            \'transaction_id\': txn_id,\n
# \'customer_name\': \'CUSTOMER\',\n            \'transaction_summary\': f\'Purchase of {qty} {style} sunglasses\',\n
# \'transaction_amount\': float(line_total),\n            \'balance_after_transaction\': float(balance),\n
# \'timestamp\': datetime.utcnow().isoformat()\n        }\n        transactions_tbl.insert(txn)\n
# txn_ids.append(txn_id)\n\n    # 4. Set final response based on outcome\n    if insufficient:\n        # rollback
# not needed because we stopped before any mutation for this item,\n        # but earlier items may have already been
# mutated – per policy we should not mutate at all.\n        # To honor policy, we revert any prior updates.\n
# # Simple approach: reload original stock values from DB backup is unavailable,\n        # so we treat this as a dry
# run instead of mutation.\n        # We\'ll set STATUS and answer_text without committing changes.\n        # Since
# we already mutated earlier items, we need to undo:\n        # Re-add the deducted stock and revert balance and
# delete inserted transactions.\n        # Undo loop for items already processed (order_items before the failing
# one)\n        processed = order_items[:order_items.index((style, qty))]\n        for p_style, p_qty in processed:\n
# p_item = inventory_tbl.search(Item.name == p_style)[0]\n            # restore stock\n
# inventory_tbl.update({\'quantity_in_stock\': p_item[\'quantity_in_stock\'] + p_qty},\n
# Item.item_id == p_item[\'item_id\'])\n        # Remove inserted transactions\n        for tid in txn_ids:\n
# transactions_tbl.remove(Query().transaction_id == tid)\n        answer_text = insufficient_msg\n        STATUS =
# "insufficient_stock"\n        print(f"LOG: ACTION=mutate SHOULD_MUTATE=False STATUS={STATUS}")\n    elif
# \'answer_text\' not in locals():\n        answer_text = "Your purchase is confirmed: 3 Classic and 1 Aviator
# sunglasses have been reserved for you."\n        STATUS = "success"\n        print(f"LOG: ACTION={ACTION}
# SHOULD_MUTATE=True STATUS={STATUS}")\n    # else answer_text already set for no_match case',
#         'stdout': 'LOG: ACTION=mutate SHOULD_MUTATE=True STATUS=success',
#         'error': None,
#         'answer': 'Your purchase is confirmed: 3 Classic and 1 Aviator sunglasses have been reserved for you.',
#         'inventory_after': [
#             {
#                 'item_id': 'SG001',
#                 'name': 'Aviator',
#                 'description': 'Originally designed for pilots, these teardrop-shaped lenses with thin metal frames
# offer timeless appeal. The large lenses provide excellent coverage while the lightweight construction ensures
# comfort during long wear.',
#                 'quantity_in_stock': 22,
#                 'price': 80
#             },
#             {
#                 'item_id': 'SG002',
#                 'name': 'Wayfarer',
#                 'description': 'Featuring thick, angular frames that make a statement, these sunglasses combine
# retro charm with modern edge. The rectangular lenses and sturdy acetate construction create a confident look.',
#                 'quantity_in_stock': 6,
#                 'price': 95
#             },
#             {
#                 'item_id': 'SG003',
#                 'name': 'Mystique',
#                 'description': 'Inspired by 1950s glamour, these frames sweep upward at the outer corners to create
# an elegant, feminine silhouette. The subtle curves and often embellished temples add sophistication to any
# outfit.',
#                 'quantity_in_stock': 3,
#                 'price': 70
#             },
#             {
#                 'item_id': 'SG004',
#                 'name': 'Sport',
#                 'description': 'Designed for active lifestyles, these wraparound sunglasses feature a single curved
# lens that provides maximum coverage and wind protection. The lightweight, flexible frames include rubber grips.',
#                 'quantity_in_stock': 11,
#                 'price': 110
#             },
#             {
#                 'item_id': 'SG005',
#                 'name': 'Classic',
#                 'description': 'Classic round profile with minimalist metal frames, offering a timeless and
# versatile style that fits both casual and formal wear.',
#                 'quantity_in_stock': 7,
#                 'price': 60
#             },
#             {
#                 'item_id': 'SG006',
#                 'name': 'Moon',
#                 'description': 'Oversized round style with bold plastic frames, evoking retro aesthetics with a
# modern twist.',
#                 'quantity_in_stock': 10,
#                 'price': 120
#             }
#         ],
#         'transactions_after': [
#             {
#                 'transaction_id': 'TXN001',
#                 'customer_name': 'OPENING_BALANCE',
#                 'transaction_summary': 'Daily opening register balance',
#                 'transaction_amount': 500.0,
#                 'balance_after_transaction': 500.0,
#                 'timestamp': '2026-04-23T14:38:21.149711'
#             },
#             {
#                 'transaction_id': 'TXN002',
#                 'customer_name': 'CUSTOMER',
#                 'transaction_summary': 'Purchase of 3 Classic sunglasses',
#                 'transaction_amount': 180.0,
#                 'balance_after_transaction': 680.0,
#                 'timestamp': '2026-04-23T09:08:46.716508'
#             },
#             {
#                 'transaction_id': 'TXN003',
#                 'customer_name': 'CUSTOMER',
#                 'transaction_summary': 'Purchase of 1 Aviator sunglasses',
#                 'transaction_amount': 80.0,
#                 'balance_after_transaction': 760.0,
#                 'timestamp': '2026-04-23T09:08:46.725259'
#             }
#         ]
#     }
# }
